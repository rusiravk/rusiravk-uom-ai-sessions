# %% [markdown]
# # Learning Goals
#  1. Supervised vs Unsupervised Learning
#  2. Supervised Learning Workflow
#  3. Build first model using sklearn
# 4. Use correct metrics to evaluate model performance

# %% [markdown]
# # Supervised learning workflow
# 1. split data into training and testing sets
# 2. choose a model and configure its parameters
# 3. train the model on training set.
# 4. evaluate model on testing set.
# 5. fine-tune the model as needed

# %%
## Regression Problems

# V = IR + Error

# %%
import numpy as np

rng = np.random.default_rng()
n = 600
R_true = 120.0
I = rng.uniform(0, 2.0, size=(n,1))
noise = rng.normal(0, 0.1, size=(n,1))
V = R_true*I+noise

# %%
print(V)

# %%
from sklearn.model_selection import train_test_split
X_train, X_temp, Y_train, Y_temp = train_test_split(I, V.ravel(),train_size=0.3, random_state=42)
X_val, X_test, Y_val, Y_test = train_test_split(X_temp, Y_temp,test_size=0.5, random_state=42)

# %%
print(X_train, X_temp,X_test,X_val)
print(Y_train, Y_temp,Y_test,Y_val)

# %%
import matplotlib.pyplot as plt
plt.scatter(I, V,alpha=0.5)
plt.xlabel("I")
plt.ylabel("V")
plt.title("V-I")
# Out:
# Text(0.5, 1.0, 'V-I')

# %%
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error
model = LinearRegression()
model.fit(X_train, Y_train)
# Out:
# LinearRegression()

# %%
def evaluate_model(model, X, Y):
    y_pred = model.predict(X)
    mse = mean_squared_error(Y, y_pred)
    return mse
mse_val = evaluate_model(model, X_val,Y_val)
mse_test = evaluate_model(model, X_test,Y_test)

print(mse_val)
print(mse_test)
# Out:
# 0.012313405177561722
# 0.01128234911540188

# %%
mse_train = evaluate_model(model, X_train, Y_train)
print(mse_train)
# Out:
# 0.009539177305877262
